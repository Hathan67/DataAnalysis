# %% [markdown]
# <a href="https://colab.research.google.com/github/Hathan67/Hathan67/blob/main/hat_pandasdataanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
hat = pd.read_csv("/content/drive/MyDrive/python/Superstore.csv")
#to write and store csv file use hat.to_csv('hathan.csv',index=false,columns =['columns to export'])
""" methods to write csv """
#skiprows=1 skips the 1st row also specify header=1
#header = none and names = column names removes and gives the column names
#nrows = n limits the rows the pd read
#na_values=[wrong values in the table] it haneges the values to NaN
# Out:
# ' methods to write csv '

# %%
hat
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3          4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4          5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
hat.shape
# Out:
# (9994, 21)

# %% [markdown]
# Change the type of Date Column

# %%
hat['Order Date']=pd.to_datetime(hat['Order Date'])

# %%
hat.info()

# %%
hat.sort_values(['Order Date','Ship Date'],inplace=True,ascending=True)
hat.head(10)
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 540      541  CA-2014-140795 2014-01-02  03-02-2014     First Class
# 5713    5714  US-2014-143707 2014-01-03  05-03-2014  Standard Class
# 6547    6548  CA-2014-113880 2014-01-03  05-03-2014  Standard Class
# 6548    6549  CA-2014-113880 2014-01-03  05-03-2014  Standard Class
# 7947    7948  CA-2014-131009 2014-01-03  05-03-2014  Standard Class
# 7948    7949  CA-2014-131009 2014-01-03  05-03-2014  Standard Class
# 7949    7950  CA-2014-131009 2014-01-03  05-03-2014  Standard Class
# 7950    7951  CA-2014-131009 2014-01-03  05-03-2014  Standard Class
# 157      158  CA-2014-104269 2014-01-03  06-03-2014    Second Class
# 8309    8310  CA-2014-168312 2014-01-03  07-03-2014  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 540     BD-11500   Bradley Drucker     Consumer  United States      Green Bay
# ...

# %%
hat.fillna(0,inplace = True)
""" cleaning data by removing null values called data wrangling or data munging """
# Out:
# ' cleaning data by removing null values called data wrangling or data munging '

# %%
#hat.fillna({key(columns):values})
#hat.fillna(method=ffil,limit=1))
#hat.dropna()drops all olumns with na..dropna(how="all"),thersh=2 or 1 drop na rows only
#use hat.interpolate(method=time)

# %%
hat.desribe()
""" it gives the statistics of our DATA """

# %%
hat.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# give products sold more than 5500

# %%
hat[["Product Name","Category","Customer Name"]][hat["Sales"]>5500]
# Out:
#                                            Product Name         Category  \
# 165           Lexmark MX611dhe Monochrome Laser Printer       Technology
# 509   Fellowes PB500 Electric Punch Plastic Comb Bin...  Office Supplies
# 683           Cubify CubeX 3D Printer Triple Head Print       Technology
# 2505        High Speed Automatic Electric Letter Opener  Office Supplies
# 2623              Canon imageCLASS 2200 Advanced Copier       Technology
# 2697  Cisco TelePresence System EX90 Videoconferenci...       Technology
# 4098               Ibico EPK-21 Electric Binding System  Office Supplies
# 4190              Canon imageCLASS 2200 Advanced Copier       Technology
# 4277   3D Systems Cube Printer, 2nd Generation, Magenta       Technology
# 6425              Canon imageCLASS 2200 Advanced Copier       Technology
# 6626  HP Designjet T520 Inkjet Large Format Printer ...       Technology
# 6826              Canon imageCLASS 2200 Advanced Copier       Technology
# ...

# %%
hat[['Order Date','Sales','Quantity']]
# Out:
#      Order Date    Sales  Quantity
# 540  2014-01-02  468.900         6
# 5713 2014-01-03    5.940         3
# 6547 2014-01-03  634.116         6
# 6548 2014-01-03   17.472         3
# 7947 2014-01-03   18.840         5
# ...         ...      ...       ...
# 908  2017-12-30   52.776         3
# 1296 2017-12-30   13.904         2
# 1297 2017-12-30   20.720         2
# 5091 2017-12-30    3.024         3
# 645  2017-12-30  209.300         2
#
# [9994 rows x 3 columns]

# %%
idx = pd.date_range('2014-01-01','2017-12-30')
hat.groupby('Order Date')[['Sales','Quantity']].sum().sort_values(['Order Date'],ascending=False).round(2).reindex(idx,fill_value=0)
# Out:
#               Sales  Quantity
# 2014-01-01     0.00         0
# 2014-01-02   468.90         6
# 2014-01-03  2203.15        40
# 2014-01-04   119.89        12
# 2014-01-05     0.00         0
# ...             ...       ...
# 2017-12-26   814.59        12
# 2017-12-27   177.64         6
# 2017-12-28  1657.35        64
# 2017-12-29  2915.53        41
# 2017-12-30   713.79        23
#
# [1460 rows x 2 columns]

# %%
# hat.sort_values(["Order Date"],ascending=True)

# %% [markdown]
# **Pivot** **Table**

# %%
hy=hat.pivot_table(['Profit','Sales'],['Category'],aggfunc='mean')

# %%
import matplotlib

# %%
hy.plot()

# %%
hat.isnull().sum()

# %%
""" 
import pandas as pd
import numpy as np
#replace missing data
read df
create new_df=df.replace([values to be replaced{also can give as dict}],np.NaN)
dict can be column and placed value with np (or) placed:replaed as ky and val


     """

# %%
#learn regex tutorial
